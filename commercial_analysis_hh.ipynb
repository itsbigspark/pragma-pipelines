# %%
import pandas as pd
import numpy as np
from pyxlsb import convert_date

# %%
footfall = pd.read_excel('data/footfall.xlsx')
occupancy_costs = pd.read_excel('data/OccupancyCosts.xlsx')
tenancy_schedule = pd.read_excel('data/The Glades Tenancy Schedule.xlsx',
                                skiprows = 1)

# %%
name_dict = {'black cab coffee co': 'black cab coffee', 
             'apple store': 'apple',
            'and cut hair & beauty': 'and cut', 
            'caffè nero': 'caffe nero', 
            'crew clothing co.': 'crew clothing co', 
            'crystal palace football club': 'crystal palace f.c',
             'intime ': 'intime',
             'suit direct ': 'suit direct'
            }

# %%
occupancy_costs['mainCategory'] = occupancy_costs['Category']\
                                    .apply(lambda x: x.split(">>")[0])
occupancy_costs['Name'] = occupancy_costs['Name']\
                .apply(lambda x: x.lower() if isinstance(x, str) else '')
occupancy_costs = occupancy_costs.replace(name_dict)

# %%
tenancy_schedule.rename(columns = {'Shop': 'Name'}, inplace = True)
tenancy_schedule['Name'] = tenancy_schedule['Name']\
                .apply(lambda x: x.lower() if isinstance(x, str) else '')
tenancy_schedule = tenancy_schedule.replace(name_dict)

# %%
lease_expiries = pd.read_excel('data/lease_expiries.xlsx',
                               usecols=lambda x: 'Unnamed' not in x,
                               skiprows = 1, 
                               engine = 'pyxlsb')

lease_expiries.rename(columns = {'Name':'Number', 'Shop':'Name'},
                      inplace = True)

lease_expiries['Name'] = lease_expiries['Name']\
                            .apply(lambda x: x.lower() if isinstance(x, str) else '')

lease_expiries = lease_expiries.replace(name_dict)

# %%
fact_table = occupancy_costs.merge(tenancy_schedule,
                                   on = 'Name', how = 'outer')\
                            .merge(lease_expiries, 
                                   on = 'Name',
                                   how = 'outer')\
                            .sort_values(by = 'Name') \
                            .drop_duplicates()

# %%
clean_table = fact_table[fact_table.Name !=''].sort_values(by='Name')
clean_table['rent_review'] = clean_table['Rent Type Of Review'].apply(lambda x: 1 if isinstance(x, str) else 0)

# %%
fact_table.groupby(['Floor', 'Let Status']).count()['Name']
# Out:
# Floor  Let Status
# Lower  Let                   75
#        Let [Shop Closed]      1
#        Vacant               312
# Upper  Let                   46
#        Let [Shop Closed]      1
#        Vacant               288
# Name: Name, dtype: int64

# %%
clean_table.groupby(['Floor', 'rent_review']).count()['Name']
# Out:
# Floor  rent_review
# Lower  0              37
#        1              39
# Upper  0              25
#        1              22
# Name: Name, dtype: int64

# %%
#what is the percentage of selling space?
# sell that somebody can sell in

# %%
lease_expiries.groupby(['Floor', 'Let Status']).count()['Name']
# Out:
# Floor  Let Status
# Lower  Let                  72
#        Let [Shop Closed]     1
#        Vacant               13
# Upper  Let                  43
#        Let [Shop Closed]     1
#        Vacant               12
# Name: Name, dtype: int64

# %%
#find interesting aggregations to make of the datasets
#maybe make the visualizations myself?

#look at data for visitors and community, decide whether 
#it is feasible to get them in the next three/four weeks

# %%
clean_table.groupby('mainCategory').count()['Name']
# Out:
# mainCategory
# Clothing & Accessories                 8
# Clothing & Accessories                37
# Department & Variety Stores            4
# Health & Beauty                        9
# Health & Beauty                       18
# Household & Electrical & Hardware      2
# Household & Electrical & Hardware      3
# Leisure                                1
# Multimedia & Gifts                     4
# Multimedia & Gifts                    13
# Other Retail                           1
# Other Retail                           3
# Restaurants & Bars                     6
# Restaurants & Bars                    11
# Services                               2
# Services                               1
# Name: Name, dtype: int64

# %%
clean_table.head()
# Out:
#             Name DateOpened  \
# 0   ada & albert 2020-12-16
# 1           aldo        NaT
# 2        and cut        NaT
# 3          apple        NaT
# 4  auntie anne's        NaT
#
#                                             Category  GrossSqFt       Rent_x  \
# 0  Clothing & Accessories >> Women's Wear >> Ladi...        NaN          NaN
# 1           Clothing & Accessories >> Shoes >> Shoes     2229.0   £45,000.00
# 2                    Health & Beauty >> Hairdressing      475.0   £20,000.00
# 3                  Household & Electrical & Hardware     4935.0  £315,000.00
# 4         Restaurants & Bars >> Fast Food Restaurant      406.5   £56,000.00
#
#   ServiceCharge  Insurance        Rates        Total TotalPerGrossSqFt  ...  \
# 0           NaN        NaN          NaN        £0.00               NaN  ...
# 1    £26,400.93  £1,028.80   £59,160.00  £131,589.73            £59.04  ...
# 2     £5,023.83    £271.18    £7,680.00   £32,975.01            £69.42  ...
# 3    £57,163.00  £3,053.00  £101,065.00  £476,281.00            £96.51  ...
# 4     £4,378.79    £308.61   £20,582.75   £81,270.15           £199.93  ...
#
#    Floor       Number  Unit Type Let Status  Lease Review  \
# 0  Lower           58        NaN        Let           NaN
# 1  Lower           57        NaN        Let           NaN
# 2  Lower           77        NaN        Let           NaN
# 3  Lower  087/088/094        NaN        Let       43007.0
# 4  Lower           25        NaN        Let       42276.0
#
#                     Break Clause Lease Expiry_y Service Charge    Rent_y  \
# 0                            NaN            NaN            NaN       NaN
# 1  Rolling break from 17/06/2016        43998.0       26400.93   45000.0
# 2                            NaN        44690.0        5023.83   20000.0
# 3                            NaN        44832.0       52396.65  315000.0
# 4                            NaN        44102.0        4378.79   56000.0
#
#   rent_review
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
#
# [5 rows x 58 columns]

# %%
dates = ['DateOpened', 'Lease Expiry_x', 'Lease Expiry_y', 'Lease Review']

# %%
clean_table[dates] = clean_table[dates].fillna(0)

# %%
clean_table[dates].head()
# Out:
#             DateOpened Lease Expiry_x  Lease Expiry_y  Lease Review
# 0  2020-12-16 00:00:00              0             0.0           0.0
# 1                    0     16/06/2020         43998.0           0.0
# 2                    0     09/05/2022         44690.0           0.0
# 3                    0     28/09/2022         44832.0       43007.0
# 4                    0     28/09/2020         44102.0       42276.0

# %%
clean_table['Lease Expiry_y'] = clean_table['Lease Expiry_y'].apply(lambda x: format(convert_date(x), '%Y-%m-%d'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ss/rw4835md0qv6sdmndxyr4r580000gn/T/ipykernel_26550/4067822512.py in <module>
# ----> 1 clean_table['Lease Expiry_y'] = clean_table['Lease Expiry_y'].apply(lambda x: format(convert_date(x), '%Y-%m-%d'))
#       2 clean_table['Lease Review'] = clean_table['Lease Review'].apply(lambda x: format(convert_date(x), '%Y-%m-%d'))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/ss/rw4835md0qv6sdmndxyr4r580000gn/T/ipykernel_26550/4067822512.py in <lambda>(x)
# ----> 1 clean_table['Lease Expiry_y'] = clean_table['Lease Expiry_y'].apply(lambda x: format(convert_date(x), '%Y-%m-%d'))
#       2 clean_table['Lease Review'] = clean_table['Lease Review'].apply(lambda x: format(convert_date(x), '%Y-%m-%d'))
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
clean_table['Lease Review'] = clean_table['Lease Review'].apply(lambda x: format(convert_date(x), '%Y-%m-%d'))

# %%
clean_table[dates].head()
# Out:
#             DateOpened Lease Expiry_x Lease Expiry_y Lease Review
# 0  2020-12-16 00:00:00              0     1900-01-01   1900-01-01
# 1                    0     16/06/2020     2020-06-16   1900-01-01
# 2                    0     09/05/2022     2022-05-09   1900-01-01
# 3                    0     28/09/2022     2022-09-28   2017-09-29
# 4                    0     28/09/2020     2020-09-28   2015-09-29

# %%
clean_table = clean_table.drop(['Lease Expiry_x'], axis=1)

# %%
clean_table.head()
# Out:
#             Name           DateOpened  \
# 0   ada & albert  2020-12-16 00:00:00
# 1           aldo                    0
# 2        and cut                    0
# 3          apple                    0
# 4  auntie anne's                    0
#
#                                             Category  GrossSqFt       Rent_x  \
# 0  Clothing & Accessories >> Women's Wear >> Ladi...        NaN          NaN
# 1           Clothing & Accessories >> Shoes >> Shoes     2229.0   £45,000.00
# 2                    Health & Beauty >> Hairdressing      475.0   £20,000.00
# 3                  Household & Electrical & Hardware     4935.0  £315,000.00
# 4         Restaurants & Bars >> Fast Food Restaurant      406.5   £56,000.00
#
#   ServiceCharge  Insurance        Rates        Total TotalPerGrossSqFt  ...  \
# 0           NaN        NaN          NaN        £0.00               NaN  ...
# 1    £26,400.93  £1,028.80   £59,160.00  £131,589.73            £59.04  ...
# 2     £5,023.83    £271.18    £7,680.00   £32,975.01            £69.42  ...
# 3    £57,163.00  £3,053.00  £101,065.00  £476,281.00            £96.51  ...
# 4     £4,378.79    £308.61   £20,582.75   £81,270.15           £199.93  ...
#
#    Floor       Number  Unit Type Let Status  Lease Review  \
# 0  Lower           58        NaN        Let    1900-01-01
# 1  Lower           57        NaN        Let    1900-01-01
# 2  Lower           77        NaN        Let    1900-01-01
# 3  Lower  087/088/094        NaN        Let    2017-09-29
# 4  Lower           25        NaN        Let    2015-09-29
#
#                     Break Clause Lease Expiry_y Service Charge    Rent_y  \
# 0                            NaN     1900-01-01            NaN       NaN
# 1  Rolling break from 17/06/2016     2020-06-16       26400.93   45000.0
# 2                            NaN     2022-05-09        5023.83   20000.0
# 3                            NaN     2022-09-28       52396.65  315000.0
# 4                            NaN     2020-09-28        4378.79   56000.0
#
#    rent_review
# 0            0
# 1            0
# 2            0
# 3            1
# 4            1
#
# [5 rows x 57 columns]

# %%
clean_table.to_csv('~/Desktop/clean_table_clean.csv')
